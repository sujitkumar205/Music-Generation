# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
% pylab inline
import glob
import numpy as np
import pandas as pd
from music21 import converter, instrument, note, chord, stream
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import CuDNNLSTM, LSTM, Bidirectional
from keras.layers import Activation
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint, History
from keras.models import load_model
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def train_network():
    # Get notes from midi files
    notes = get_notes()

    # Get the number of pitch names
    n_vocab = len(set(notes))

    # Convert notes into numerical input
    network_input, network_output = prepare_sequences(notes, n_vocab)

    # Set up the model
    model = create_network(network_input, n_vocab)
    history = History()
    
    # Fit the model
    n_epochs = 15
    model.summary()
    model.fit(network_input, network_output, callbacks=[history], epochs=n_epochs, batch_size=64)
    model.save('/content/gdrive/MyDrive/AI_Project/LSTMmodel.h5')
    
    # Use the model to generate a midi
    prediction_output = generate_notes(model, notes, network_input, len(set(notes)))
    create_midi(prediction_output, 'pokemon_midi')
    
    # Plot the model losses
    pd.DataFrame(history.history).plot()
    plt.savefig('LSTM_Loss_per_Epoch.png', transparent=True)
    plt.close()

# %%
def get_notes():
    """ Get all the notes and chords from the midi files """
    notes = []

    for file in glob.glob("/content/gdrive/MyDrive/AI_Project/Pokemon/*.mid"):
        midi = converter.parse(file)

        print("Parsing %s" % file)

        notes_to_parse = None

        try: # file has instrument parts
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: # file has notes in a flat structure
            notes_to_parse = midi.flat.notes
            
        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))

    return notes

# %%
def prepare_sequences(notes, n_vocab):
    """ Prepare the sequences used by the Neural Network """
    sequence_length = 100

    # get all pitch names
    pitchnames = sorted(set(item for item in notes))

     # create a dictionary to map pitches to integers
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))

    network_input = []
    network_output = []

    # create input sequences and the corresponding outputs
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_input.append([note_to_int[char] for char in sequence_in])
        network_output.append(note_to_int[sequence_out])

    # reshape the input into a format compatible with LSTM layers
    n_patterns = len(network_input)
    network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
    
    # normalize input between 0 and 1
    network_input = network_input / float(n_vocab)

    network_output = np_utils.to_categorical(network_output)

    return (network_input, network_output)

# %%
def create_network(network_input, n_vocab):
    """ create the structure of the neural network """
    model = Sequential()
    model.add(CuDNNLSTM(512,input_shape=(network_input.shape[1], network_input.shape[2]),return_sequences=True))
    model.add(Dropout(0.3))
    model.add(Bidirectional(CuDNNLSTM(512, return_sequences=True)))
    model.add(Dropout(0.3))
    model.add(Bidirectional(CuDNNLSTM(512)))
    model.add(Dense(256))
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    return model

# %%
def generate_notes(model, notes, network_input, n_vocab):
    """ Generate notes from the neural network based on a sequence of notes """
    # pick a random sequence from the input as a starting point for the prediction
    pitchnames = sorted(set(item for item in notes))
    
    start = np.random.randint(0, len(network_input)-1)

    int_to_note = dict((number, note) for number, note in enumerate(pitchnames))

    pattern = network_input[start]
    prediction_output = []

    # generate 500 notes
    for note_index in range(500):
        prediction_input = np.reshape(pattern, (1, len(pattern), 1))
        prediction_input = prediction_input / float(n_vocab)

        prediction = model.predict(prediction_input, verbose=0)

        index = np.argmax(prediction)
        result = int_to_note[index]
        prediction_output.append(result)
        
        pattern = np.append(pattern,index)
        pattern = pattern[1:len(pattern)]

    return prediction_output

# %%
def create_midi(prediction_output, filename):
    """ convert the output from the prediction to notes and create a midi file
        from the notes """
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for pattern in prediction_output:
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)
        # increase offset each iteration so that notes do not stack
        offset += 0.5

    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp='{}.mid'.format(filename))
    print("hello")

# %%
if __name__ == '__main__':
    train_network()

# %%
notes = get_notes()
# Out:
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Research Lab.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Surf.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon HeartGoldSoulSilver - Cerulean City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Battle Wild Pokemon.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Dragons Den.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Temporal Tower.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Game Corner.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Mystery Gift.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Bicycle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Battle Trainer.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon BlueRed Rescue Team - Sinister Woods.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Colosseum - Semifinal Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Gym Leader Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Icirrus City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Drenched Bluff.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon BlueRed Rescue Team - Questionnaire.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Verdanturf Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Apple Woods.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Accumula Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon HeartGoldSoulSilver - Game Corner.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Pinball - Catch Em and Evolution Mode in Red Field.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon XY - Bicycle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon - Littleroot Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Trainer Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Saffron City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Champion Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Champion Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Mt Moon.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Battle CherenBianca.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Time Gear Remix.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Petalburg City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Sealed Ruin Pit.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Battle Team Galactic Admin.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Lacunosa Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Sandgem Town Day.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Pallet Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Dark Cave.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Poketch Addition.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Spacial Cliffs.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Battle Team Plasma.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Gym Leader Defeated.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Champion Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon HeartGoldSoulSilver - Pokemon Center.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Route 12.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Steam Cave.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon HeartGoldSoulSilver - PokeWalker Synchronisation.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - In the Hands of Fate.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Route 205 Night.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon - The Ghost at Maiden's Peak.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Evergrande City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Oldale Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon XY - FIN.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Johto Wild Pokemon Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Intro 1.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Oh No.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Elite Four.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Dewford Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Title Theme.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - WiFi Lobby.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Intro 2.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Battle Wild Pokemon.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Lavender Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite -
mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Trading Card Game - Title Screen.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon HeartGoldSoulSilver - Route 4748.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Bug Catching Contest.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon XY - Battle Wild Pokemon.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Celadon City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Team Charms Theme.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Team RocketRadio Tower Takeover.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Champion Alder.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Route 24.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Black 2White 2 - Ns Room.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Recovery.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - White Forest.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Heartwarming.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon HeartGoldSoulSilver - Indigo Plateau.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Route 10.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Pokemon March.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Battle Tower.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Colosseum - Pyrite Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Pokemon Tower.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Rival Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon BlueRed Rescue Team - Sky Tower.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon BlueRed Rescue Team - Great Canyon.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon BlueRed Rescue Team - Escape Through the Snow  Snow Refugees.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Girl Trainer Confrontation.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Hidden Land.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Lower Brine Cave.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Black 2White 2 - Ns Theme.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Lavender Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Wild Pokemon Caught or Fainted.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Show Me Around.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon - Lugias Song.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Pokemon League Day.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Surfing.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Yellow - Lavender Town (Fixed).mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Driftveil City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Musical Hall.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - N the Pokemon Child.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Palkias Onslaught.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Wild Pokemon Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Stark Mountain.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Old Chateau.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Foggy Forest.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Ending Theme.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Guildmaster Wigglytuff.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Defend Globe.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Heavy Rain.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Rival Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Aegis Cave.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Eterna City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Gold, Silver, Crystal - Cinnabar Island (HGSS Version).mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Elite 4 Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Hearthome City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Black 2White 2 - Cave of Being.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Olivine Lighthouse.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Burned Tower.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - National Park.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Desert.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Pokemon Lullaby.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Undella Town Summer.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Colosseum - The Under.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Lilycove City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Explorers of TimeDarknessSky - Spindas Cafe.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Viridian Forest.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Pokemon Center.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Dragonspiral Tower.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Dance Theatre.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Cyrus  Team Galactic Boss Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Snap - A Mysterious Sighting.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Azelf Mesprit and Uxie Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Wild Pokemon Battle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon - pokecentre theme.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Route 225 Night.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Professor Oaks Theme.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Route 29.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Opelucid City White.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Black & White - Village Bridge.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Route 104.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Pokemon Contest.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon XY - Route 4567.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Ns Castle.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Indigo Plateau.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Spear Pillar.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon BlueRed Rescue Team - Friend Area  Swamp.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Mt Pyre Peak.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon X and Y - Calem and Serena.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Gold, Silver, Crystal - S.S. Aqua .mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Surf Theme.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RedBlueYellow - Oaks Lab.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Colosseum - Outskirt Stand.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Mt Coronet.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Undella Town FallWinterSpring.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Skyarrow Bridge.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon XD Gale of Darkness - The Hexagon Bros.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon Mystery Dungeon Gates to Infinity - File Select.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Route 38.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Fallarbor Town.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon RubySapphireEmerald - Fortree City.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon GoldSilverCrystal - Route 32.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Pokemon League.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Battle Rival.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon BlackWhite - Ending Onward to Our Own Futures.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Approaching Champion Cynthia.mid
# Parsing /content/gdrive/MyDrive/AI_Project/Pokemon/Pokemon DiamondPearlPlatinum - Battle Champion.mid

# %%
def makePred():

    # Get the number of pitch names
    n_vocab = len(set(notes))

    # Convert notes into numerical input
    network_input, network_output = prepare_sequences(notes, n_vocab)

    # Set up the model
    model = create_network(network_input, n_vocab)

    model = load_model('/content/gdrive/MyDrive/AI_Project/LSTMmodel.h5')

    prediction_output = generate_notes(model, notes, network_input, len(set(notes)))
    create_midi(prediction_output, '/content/gdrive/MyDrive/AI_Project/Output/LSTMpokemon_midi')

# %%
makePred()
# Out:
# hello
